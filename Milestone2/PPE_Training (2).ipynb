# %% [markdown]
# # PPE Compliance Monitoring System - Model Training
# **L&T EduTech AI Edge Project**
#
# **Name:** Sneha H S
#
# **Date:** 06-06-2026
#
# **Objective:** Train YOLOv11 Nano model to detect PPE violations on construction sites.
#
# **Dataset:** PPE-Compliance-Final — 4 datasets merged (Helmet, Vest, Goggles, Boots)
# - Total images: 11,942
# - After augmentation: 29,366
# - Classes: 11

# %%
# Step 1 - Check GPU
# !nvidia-smi

# %%
# Step 2 - Set working directory
import os
HOME = os.getcwd()
print(HOME)

# %%
# Step 3 - Install libraries
# %pip install "ultralytics<=8.3.40" supervision roboflow -q
# !yolo settings sync=False
import ultralytics
ultralytics.checks()

# %%
# Step 4 - Download dataset from Roboflow
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata
from roboflow import Roboflow

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
rf = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf.workspace('sneha-h-s-dcket').project('ppe-compliance-final-iu1a8')
version = project.version(1)
dataset = version.download('yolov11')

# %%
# Step 5 - Check dataset classes
import yaml
with open(f'{dataset.location}/data.yaml', 'r') as f:
    config = yaml.safe_load(f)

print(f"Classes ({config['nc']}): {config['names']}")
